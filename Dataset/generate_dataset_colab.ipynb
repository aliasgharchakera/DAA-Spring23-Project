# %% [markdown]
# <a href="https://colab.research.google.com/github/aliasgharchakera/DAA-Spring23-Project/blob/master/Dataset/generate_dataset_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cloning the repo; Running the script

# %%
! rm -rvf DAA-Spring23-Project/
! git clone https://github.com/aliasgharchakera/DAA-Spring23-Project/
! cd /content/DAA-Spring23-Project/Dataset/scripts && python generate_dataset.py
# Out:
# Cloning into 'DAA-Spring23-Project'...
# remote: Enumerating objects: 19299, done.
# remote: Counting objects: 100% (6056/6056), done.
# remote: Compressing objects: 100% (5162/5162), done.
# remote: Total 19299 (delta 899), reused 6048 (delta 894), pack-reused 13243
# Receiving objects: 100% (19299/19299), 264.39 MiB | 14.72 MiB/s, done.
# Resolving deltas: 100% (3494/3494), done.
# Updating files: 100% (6102/6102), done.

# %% [markdown]
# # Configure github; Stage Changes; Commit them

# %%
# Your Name there
! git config --global user.email "abbastaqvi81@gmail.com"
# Your username there
! git config --global user.name "smabbasht"
# Staging Changes, Commiting changes, Writing a good commit message
! cd /content/DAA-Spring23-Project/ && git add * && git commit -m "update the instances"
# Out:
# Streaming output truncated to the last 5000 lines.
#  rewrite Dataset/very_large_n_and_wmax_group/instance_0083.txt (98%)
#  rewrite Dataset/very_large_n_and_wmax_group/instance_0084.txt (98%)
#  rewrite Dataset/very_large_n_and_wmax_group/instance_0085.txt (97%)
#  rewrite Dataset/very_large_n_and_wmax_group/instance_0086.txt (91%)
#  rewrite Dataset/very_large_n_and_wmax_group/instance_0087.txt (96%)
#  rewrite Dataset/very_large_n_and_wmax_group/instance_0088.txt (97%)
#  rewrite Dataset/very_large_n_and_wmax_group/instance_0089.txt (78%)
#  rewrite Dataset/very_large_n_and_wmax_group/instance_0090.txt (63%)
#  rewrite Dataset/very_large_n_and_wmax_group/instance_0091.txt (98%)
#  rewrite Dataset/very_large_n_and_wmax_group/instance_0092.txt (98%)
#  rewrite Dataset/very_large_n_and_wmax_group/instance_0093.txt (86%)
#  rewrite Dataset/very_large_n_and_wmax_group/instance_0095.txt (88%)
#  rewrite Dataset/very_large_n_and_wmax_group/instance_0097.txt (98%)
# ...

# %% [markdown]
# # Pushing the commit
# The commit could only be pushed from Colab using an Access token from Github so you have to generate an access token which is too easy to generate:
# - Either use this [link](https://github.com/settings/tokens/new)
# - Head over to github.com > Settings > Developer Settings > Generate new token
#
# Then just add description and checkmark all the boxes (not all are required btw) > Click on Generate Token and copy the token. <br>
# Paste it after https:// below, the format of the link is also attached just fyi
# > https://\<accesstoken>@github.com/\<username>/\<repopath>.git
#
# My account's token is attached right now, If it works, you could just run the cell but it's not recommended. The token usually get's revoked if it observes suspicious accounts.

# %%
! cd /content/DAA-Spring23-Project/ && git push https://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@github.com/aliasgharchakera/DAA-Spring23-Project.git
# Out:
# Enumerating objects: 6211, done.
# Counting objects: 100% (6211/6211), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6011/6011), done.
# Writing objects: 100% (6011/6011), 89.62 MiB | 3.95 MiB/s, done.
# Total 6011 (delta 895), reused 0 (delta 0)
# remote: Resolving deltas: 100% (895/895), completed with 17 local objects.
# To https://github.com/aliasgharchakera/DAA-Spring23-Project.git
#    9615b334..3f813cd5  master -> master
